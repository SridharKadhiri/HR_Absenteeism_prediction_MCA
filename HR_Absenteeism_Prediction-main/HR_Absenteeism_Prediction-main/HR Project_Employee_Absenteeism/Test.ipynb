# %% [markdown]
# #### Absenteeism Module testing file
#
#     creating a module with methods
#
#         1. load_clean_data  - loads the new data and cleans it along with scaling
#         2. predicted_probability - gets the probability for each record
#         3. predicted_output_category - gets the predited value
#         4. predicted_outputs - displays the dataframe with probability and prediction
#         5. __init__

# %%
from Absenteeism_module import *

# %%
# getting the new data and cleaning 
new_data = 'data_raw_new.xls'


ab_mod = Absenteeism_module()


ab_mod.load_n_clean(new_data)

cleaned_data = ab_mod.data 
cleaned_data.head()
# Out:
#    Reason_1  Reason_2  Reason_3  Reason_4  Month of absence  Day of the week  \
# 0     False     False     False      True                 7                3
# 1     False     False     False     False                 7                3
# 2     False     False     False      True                 7                4
# 3      True     False     False     False                 7                5
# 4     False     False     False      True                 7                5
#
#    Transportation expense  Distance from Residence to Work  \
# 0                     289                               36
# 1                     118                               13
# 2                     179                               51
# 3                     279                                5
# 4                     289                               36
#
#    Work load Average/day   Education  Son  Pet  Body mass index  \
# 0                  239554          0    2    1               30
# 1                  239554          0    1    0               31
# 2                  239554          0    0    0               31
# 3                  239554          0    2    0               24
# 4                  239554          0    2    1               30
#
#    Excessive Absentise
# 0                    1
# 1                    0
# 2                    0
# 3                    1
# 4                    0

# %% [markdown]
# # Scaling the data

# %%
columns_to_scale = ['Month of absence',
            'Day of the week', 'Transportation expense',
            'Distance from Residence to Work', 'Work load Average/day ','Son', 'Pet', 'Body mass index']
cus_scale = CustomScaler(columns_to_scale)

scaled_data = cus_scale.fit_transform(cleaned_data)
scaled_data.head()
# Out:
#    Reason_1  Reason_2  Reason_3  Reason_4  Month of absence  Day of the week  \
# 0     False     False     False      True           0.23857        -0.642974
# 1     False     False     False     False           0.23857        -0.642974
# 2     False     False     False      True           0.23857         0.059812
# 3      True     False     False     False           0.23857         0.762597
# 4     False     False     False      True           0.23857         0.762597
#
#    Transportation expense  Distance from Residence to Work  \
# 0                1.108483                         0.468624
# 1               -1.551082                        -1.111977
# 2               -0.602348                         1.499451
# 3                0.952953                        -1.661752
# 4                1.108483                         0.468624
#
#    Work load Average/day   Education       Son       Pet  Body mass index  \
# 0               -0.766302          0  1.137446  0.089864         0.598627
# 1               -0.766302          0  0.073566 -0.585910         0.813813
# 2               -0.766302          0 -0.990314 -0.585910         0.813813
# 3               -0.766302          0  1.137446 -0.585910        -0.692485
# 4               -0.766302          0  1.137446  0.089864         0.598627
#
#    Excessive Absentise
# 0                    1
# 1                    0
# 2                    0
# 3                    1
# 4                    0

# %%
output = ab_mod.predicted_outputs(scaled_data.iloc[:,:-1])

# %%
((scaled_data['Excessive Absentise'] == output['Prediction']).sum())/ ((scaled_data['Excessive Absentise'] == output['Prediction']).count())
# Out:
# 0.9148936170212766

# %% [markdown]
# # 91% of the time our model is predicting the "Excessive Absentise"
